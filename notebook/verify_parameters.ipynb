# %%
from models.verify_parameters import simulation

# %%
fig = simulation(block_path="../small_blocks", Time=2000, noise_rate=0.01, delta_t=1, document_time=1000, show_result=True, save_result=False, specified_gui=None)
# Out:
# torch.Size([2000, 22]) torch.Size([4, 2000, 2000])
# window, 1
# log.max 1
# mean_fr 0.0
# cc:  3.809226
# pcc:  0.0
