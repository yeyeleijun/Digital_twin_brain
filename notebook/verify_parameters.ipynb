# %%
from models.verify_parameters import simulation

# %%
specified_gui = [2.13037975e-02, 1.39240506e-04, 1.58227848e-01, 1.89873418e-02]  # for critical in Critical_NN
fig = simulation(block_path="../small_blocks/small_blocks_zlb", Time=3000, noise_rate=0.0003, delta_t=0.1, document_time=1000, show_result=True, save_result=False, specified_gui=specified_gui)
# Out:
# torch.Size([2000, 22]) torch.Size([4, 2000, 2000])
# window, 10
# log.max 1
# mean_fr 0.015061946902654867
# cc:  1.6690887
# pcc:  0.35748345631615824
